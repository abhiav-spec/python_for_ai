# %%
text="who is pm of india"

# %%
# !pip install tiktoken

import tiktoken as tt

# %%
tokenizer=tt.encoding_for_model(model_name="gpt-4")

# %%
tokenIds=tokenizer.encode(text)
print(tokenIds)
# Out:
# [14965, 374, 9012, 315, 28811]

# %%
text=tokenizer.decode(tokenIds)
print(text)
# Out:
# who is pm of india
