# %%
val=float(input("Enter the number in float "))
print(val)
# Out:
# Enter the number in float  22.5
# 22.5

# %%
# if statement
if(val>100.0):
    print(val)
else:
    print("less than 100")
# Out:
# less than 100

# %%
# loops , while loop

# %%
lst = [1,2,3,4,5,6]

# %%
for i in lst :
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
lst = ["Abhinav" ,"kumar", "is", "my","name"]

# %%
for word in lst:
    print(word, end=" ") # Keeps everything on the same line with a space
# Out:
# Abhinav kumar is my name

# %%
type(False)
# Out:
# bool

# %%
a="Abhinav"
b="Abhinav"
print("a  and b location - " ,id(a)," ",id(b))
# Out:
# a  and b location -  4753900816   4753900816

# %%
a is b
# Out:
# True

# %%
a == b
# Out:
# True

# %%
abs(-5)
# Out:
# 5

# %%
import math
print(math.ceil(abs(-5.6)))
# Out:
# 6

# %%
import math
print(math.floor(abs(-5.6)))
# Out:
# 5

# %%
import math
print(math.exp(10))
# Out:
# 22026.465794806718

# %% [markdown]
# ## trigonometric functions

# %%
print(math.sin(-10))
# Out:
# 0.5440211108893698

# %%
print(math.tan(45))
# Out:
# 1.6197751905438615
